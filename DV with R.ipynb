# %%
titanic <- read.csv(file = "titanic.csv.csv", header = TRUE, sep = ",")

# %%
require(dplyr)
# Out:
# Loading required package: dplyr
#
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
require(datasets)
require(ggvis)
# Out:
# Loading required package: ggvis
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# "there is no package called 'ggvis'"

# %%
require(magrittr)
# Out:
# Loading required package: magrittr

# %%
titanic
# Out:
#     PassengerId Survived Pclass
# 1    1          0        3
# 2    2          1        1
# 3    3          1        3
# 4    4          1        1
# 5    5          0        3
# 6    6          0        3
# 7    7          0        1
# 8    8          0        3
# 9    9          1        3
# 10  10          1        2
# 11  11          1        3
# 12  12          1        1
# 13  13          0        3
# 14  14          0        3
# 15  15          0        3
# 16  16          1        2
# 17  17          0        3
# 18  18          1        2
# 19  19          0        3
# 20  20          1        3
# 21  21          0        2
# 22  22          1        2
# 23  23          1        3
# 24  24          1        1
# 25  25          0        3
# 26  26          1        3
# 27  27          0        3
# 28  28          0        1
# 29  29          1        3
# 30  30          0        3
# ... ...         ...      ...
# 862 862         0        2
# 863 863         1        1
# ...

# %%
# Out:
# Error in tbl_df(titanic): could not find function "tbl_df"
# Traceback:

# %%
install.packages("tibble")
library(tibble)
# Out:
# also installing the dependencies 'ellipsis', 'lifecycle', 'pillar', 'rlang', 'vctrs'
#   There are binary versions available but the source versions are later:
#           binary source needs_compilation
# lifecycle  1.0.0  1.0.1             FALSE
# pillar     1.6.0  1.6.4             FALSE
# rlang     0.4.11 0.4.12              TRUE
# tibble     3.1.1  3.1.6              TRUE
#
#   Binaries will be installed
# package 'ellipsis' successfully unpacked and MD5 sums checked
# package 'rlang' successfully unpacked and MD5 sums checked
# package 'vctrs' successfully unpacked and MD5 sums checked
# package 'tibble' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Noman Baig\AppData\Local\Temp\RtmpyeX1QM\downloaded_packages
# installing the source packages 'lifecycle', 'pillar'
#
# Warning message:
# "package 'tibble' was built under R version 3.6.3"

# %%
titanic_df <- tbl_df(titanic)

# %%
adults <- filter(titanic_df)
counts <- table(adults$Sex, adults$Pclass)
barplot(counts, main="Survival as per Gender by Class",
    xlab="Class",ylab="Number Survived", col=c("darkblue","red"),
    legend = c('Male','Female'), beside=TRUE)
# Out:
# Plot with title "Survival as per Gender by Class"

# %%
titanic$survived <- as.factor(titanic$survived) 
titanic$survived <- factor(titanic$survived,levels = c(0,1), labels = c("died", "survived"))
titanic$embarked[titanic$embarked == ""] <- NA
titanic <- na.omit(titanic)
titanic$embarked <- factor(titanic$embarked,levels = c("C","S","Q"))
titanic <- titanic[-c(3,8,10)]
# Out:
# Error in `$<-.data.frame`(`*tmp*`, survived, value = structure(integer(0), .Label = character(0), class = "factor")): replacement has 0 rows, data has 891
# Traceback:
#
# 1. `$<-`(`*tmp*`, survived, value = structure(integer(0), .Label = character(0), class = "factor"))
# 2. `$<-.data.frame`(`*tmp*`, survived, value = structure(integer(0), .Label = character(0), class = "factor"))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
adults <- filter(titanic_df)
counts <- table(adults$Survived, adults$Age)
barplot(counts, main="Survival as per Age category",
    xlab="Age Category",ylab="Number Survived", col=c("darkblue","red"),
    legend = c('Male','Female'), beside=TRUE)
# Out:
# Plot with title "Survival as per Age category"

# %%
titanic <- read.csv('titanic.csv.csv')
titanic$Survived <- as.factor(titanic$Survived) 
titanic$Survived <- factor(titanic$Survived,levels = c(0,1), labels = c("died", "survived"))
titanic$Embarked[titanic$Embarked == ""] <- NA
titanic <- na.omit(titanic)
titanic$Embarked <- factor(titanic$Embarked,levels = c("C","S","Q"))
titanic <- titanic[-c(3,8,10)]

# %%
age_group <- ifelse(titanic$Age >15, c("Adult"), c("Child"))
titanic <- titanic %>% mutate(age_group)
survived_vs_age <- table(titanic$Survived, titanic$age_group)
proportion_survived_vs_age<- prop.table(survived_vs_age,2)
barplot(proportion_survived_vs_age, main="Survival rates by age group", xlab="Age group",ylab="Survival Rate", col=c("darkblue","red"), legend =    rownames(proportion_survived_vs_age), beside= TRUE)
# Out:
# Plot with title "Survival rates by age group"
